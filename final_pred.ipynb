# %% [markdown]
# ## Libraries used
# pandas: For data manipulation and analysis.<br>
# numpy: For numerical computations.<br>
# matplotlib.pyplot: For plotting graphs and visualizations.<br>
# keras: For building and training the neural network.<br>
#     Sequential: For creating a sequential model.<br>
#     Dense: For fully connected (dense) layers.<br>
#     Dropout: For dropout layers to prevent overfitting.<br>
#     LSTM: For LSTM layers<br>
#     Bidirectional: For bidirectional LSTM layers.<br>
#     BatchNormalization: For batch normalization layers to stabilize and accelerate training.<br>
#     Input: For specifying the input shape.<br>
#     Adam: For the Adam optimizer.<br>
#     EarlyStopping: For stopping training early if the model stops improving.<br>
# sklearn.preprocessing: For feature scaling.<br>
# RobustScaler: For scaling features to make the model more robust to outliers.<br>

# %% [markdown]
# ## Model Architecture
# The model is a sequential neural network with the following layers:<br>
# <br>
# Input Layer:<br>
# <br>
# Shape: (time_step, number_of_features) which is (10, 4) in this case.<br>
# First Bidirectional LSTM Layer:<br>
# <br>
# Units: 50<br>
# return_sequences=True: This layer returns the full sequence.<br>
# Batch Normalization Layer:<br>
# <br>
# Normalizes the activations of the previous layer.<br>
# Dropout Layer:<br>
# <br>
# Dropout rate: 0.2 (20% of the units are dropped during training).<br>
# Second Bidirectional LSTM Layer:<br>
# <br>
# Units: 50<br>
# return_sequences=True: This layer returns the full sequence.<br>
# Batch Normalization Layer:<br>
# <br>
# Normalizes the activations of the previous layer.<br>
# Dropout Layer:<br>
# <br>
# Dropout rate: 0.2 (20% of the units are dropped during training).<br>
# Third Bidirectional LSTM Layer:<br>
# <br>
# Units: 50<br>
# Dense Layer:<br>
# <br>
# Units: 4 (Corresponding to the 4 features being predicted: Open, Close, % Momentum).<br>

# %% [markdown]
# ## Process of Loading the Data.<br><br>
# Load dataset: The dataset is read from a CSV file using pandas.<br><br>
# Remove NaN values: Rows with NaN values in the 'Open' or 'Close' columns are removed.<br><br>
# Calculate % Momentum: A new feature, % Momentum, is calculated based on the 'Close' prices over a 7-day period.<br><br>
# Calculate Daily Returns: Daily returns are calculated.<br><br>
# Calculate Volatility: Volatility is calculated as the rolling standard deviation of returns over a 10-day window.<br><br>
# Prepare data: The relevant columns ('Open', 'Close', '% Momentum', 'Volatility') are selected, and the 'Date' column is converted to datetime format and set as the index.<br><br>
# Feature Scaling: The data is scaled using RobustScaler.<br><br>
# Split data into training and test sets: The data is split into training and test sets.<br><br>
# Create sequences: Sequences and labels are created using a time step of 10.<br><br>

# %% [markdown]
# ## Training Parameters<br><br>
# Number of Epochs: 500 (but training can stop early if the model stops improving due to early stopping).<br><br>
# Batch Size: 64<br><br>
# Early Stopping: The training will stop early if the loss does not improve for 10 consecutive epochs, and the best weights will be restored.

# %% [markdown]
# # Final_model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional, BatchNormalization, Input
from keras.optimizers import Adam
from sklearn.preprocessing import RobustScaler
from keras.callbacks import EarlyStopping

# Load dataset
df = pd.read_csv("TATAMOTORS.NS2.csv")

# Remove rows with NaN values in 'Open' or 'Close' columns
df = df.dropna(subset=['Open', 'Close'])

# Calculate % Momentum feature
n = 7  # Number of days for momentum calculation
df['% Momentum'] = (df['Close'].diff(n) / df['Close'].shift(n)) * 100  # % Momentum

# Handle NaN values in % Momentum
df['% Momentum'].fillna(0, inplace=True)

# Calculate daily returns
df['Returns'] = df['Close'].pct_change()

# Calculate rolling standard deviation of returns as volatility
volatility_window = 10  # Adjust the window size as needed
df['Volatility'] = df['Returns'].rolling(window=volatility_window).std()

# Handle NaN values in Volatility
df['Volatility'].fillna(df['Volatility'].mean(), inplace=True)

# Prepare data including % Momentum and Volatility features
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
data = df[['Open', 'Close', '% Momentum', 'Volatility']]

# Feature Scaling with adjusted range for RobustScaler
sc = RobustScaler()
data_scaled = sc.fit_transform(data)

# Define a smaller time_step
time_step = 10

# Split the data into training and test sets
train_data = data_scaled[:8426]
test_data = data_scaled[8426:]

# Function to create sequences
def create_sequence(dataset, time_step):
    sequences = []
    labels = []
    for start_idx in range(len(dataset) - time_step):
        end_idx = start_idx + time_step
        sequences.append(dataset[start_idx:end_idx])
        labels.append(dataset[end_idx])
    return np.array(sequences), np.array(labels)

# Create sequences with time step
train_seq, train_label = create_sequence(train_data, time_step)

# Check shapes of the sequences and labels
print(f"Train sequences shape: {train_seq.shape}")
print(f"Train labels shape: {train_label.shape}")

# Build the LSTM model with input layer
model = Sequential()
model.add(Input(shape=(time_step, train_seq.shape[2])))
model.add(Bidirectional(LSTM(units=50, return_sequences=True, activation='relu')))  # Reduced units with ReLU
model.add(BatchNormalization())
model.add(Dropout(0.2))  # Reduced dropout
model.add(Bidirectional(LSTM(units=50, return_sequences=True, activation='relu')))  # Reduced units with ReLU
model.add(BatchNormalization())
model.add(Dropout(0.2))  # Reduced dropout
model.add(Bidirectional(LSTM(units=50, activation='relu')))  # Reduced units with ReLU
model.add(Dense(4))  # Last dense layer with 4 units

# Compile the model with adjusted learning rate
optimizer = Adam(learning_rate=1e-4, clipvalue=0.5)  # Adjusted learning rate and gradient clipping
model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['mean_absolute_error'])

# Train the model with early stopping
early_stopping = EarlyStopping(monitor='loss', patience=10, restore_best_weights=True)
history = model.fit(train_seq, train_label, epochs=500, batch_size=64, verbose=1, callbacks=[early_stopping])

# Make predictions for the next 30 days
predictions = []
input_seq = train_data[-time_step:].reshape(1, time_step, train_seq.shape[2])

for _ in range(30):
    predicted = model.predict(input_seq)
    predictions.append(predicted[0])
    input_seq = np.append(input_seq[:, 1:, :], predicted.reshape(1, 1, train_seq.shape[2]), axis=1)

# Inverse transform the predictions
predictions = np.array(predictions)
predictions_inverse = sc.inverse_transform(predictions)

# Create dates for the predicted data
predicted_dates = pd.date_range(start=df.index[-1], periods=30)

# Create a DataFrame for visualization
predicted_df = pd.DataFrame(predictions_inverse, index=predicted_dates, columns=['Predicted_Open', 'Predicted_Close', 'Predicted_%_Momentum', 'Predicted_Volatility'])
# Out:
# C:\Users\iamha\AppData\Local\Temp\ipykernel_2864\1500726266.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['% Momentum'].fillna(0, inplace=True)
# C:\Users\iamha\AppData\Local\Temp\ipykernel_2864\1500726266.py:31: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Volatility'].fillna(df['Volatility'].mean(), inplace=True)
# Train sequences shape: (8416, 10, 4)
# Train labels shape: (8416, 4)
# Epoch 1/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 15s 33ms/step - loss: 0.7501 - mean_absolute_error: 0.5802
# Epoch 2/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - loss: 0.3786 - mean_absolute_error: 0.3945
# Epoch 3/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - loss: 0.3029 - mean_absolute_error: 0.3486
# Epoch 4/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 0.2485 - mean_absolute_error: 0.3271
# Epoch 5/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.2366 - mean_absolute_error: 0.3110
# Epoch 6/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.2053 - mean_absolute_error: 0.2981
# Epoch 7/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.1969 - mean_absolute_error: 0.2893
# Epoch 8/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.1923 - mean_absolute_error: 0.2798
# Epoch 9/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.1671 - mean_absolute_error: 0.2734
# Epoch 10/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.1813 - mean_absolute_error: 0.2733
# Epoch 11/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.1671 - mean_absolute_error: 0.2608
# Epoch 12/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.1575 - mean_absolute_error: 0.2574
# Epoch 13/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.1516 - mean_absolute_error: 0.2496
# Epoch 14/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.1371 - mean_absolute_error: 0.2442
# Epoch 15/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.1490 - mean_absolute_error: 0.2415
# Epoch 16/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.1368 - mean_absolute_error: 0.2375
# Epoch 17/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.1343 - mean_absolute_error: 0.2392
# Epoch 18/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.1295 - mean_absolute_error: 0.2315
# Epoch 19/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.1213 - mean_absolute_error: 0.2255
# Epoch 20/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.1244 - mean_absolute_error: 0.2268
# Epoch 21/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.1235 - mean_absolute_error: 0.2252
# Epoch 22/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 0.1264 - mean_absolute_error: 0.2214
# Epoch 23/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.1212 - mean_absolute_error: 0.2198
# Epoch 24/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.1211 - mean_absolute_error: 0.2194
# Epoch 25/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.1153 - mean_absolute_error: 0.2139
# Epoch 26/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.1141 - mean_absolute_error: 0.2149
# Epoch 27/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1158 - mean_absolute_error: 0.2159
# Epoch 28/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1175 - mean_absolute_error: 0.2148
# Epoch 29/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.1159 - mean_absolute_error: 0.2080
# Epoch 30/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.1105 - mean_absolute_error: 0.2086
# Epoch 31/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.1108 - mean_absolute_error: 0.2088
# Epoch 32/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.1075 - mean_absolute_error: 0.2056
# Epoch 33/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.1106 - mean_absolute_error: 0.2030
# Epoch 34/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.1149 - mean_absolute_error: 0.2049
# Epoch 35/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 0.1060 - mean_absolute_error: 0.2021
# Epoch 36/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.1018 - mean_absolute_error: 0.1992
# Epoch 37/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0966 - mean_absolute_error: 0.1964
# Epoch 38/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.1023 - mean_absolute_error: 0.1966
# Epoch 39/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0960 - mean_absolute_error: 0.1956
# Epoch 40/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 0.1004 - mean_absolute_error: 0.1953
# Epoch 41/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0954 - mean_absolute_error: 0.1931
# Epoch 42/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.1023 - mean_absolute_error: 0.1944
# Epoch 43/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0930 - mean_absolute_error: 0.1893
# Epoch 44/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0965 - mean_absolute_error: 0.1885
# Epoch 45/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.1069 - mean_absolute_error: 0.1945
# Epoch 46/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0966 - mean_absolute_error: 0.1913
# Epoch 47/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0914 - mean_absolute_error: 0.1894
# Epoch 48/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0956 - mean_absolute_error: 0.1863
# Epoch 49/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0938 - mean_absolute_error: 0.1874
# Epoch 50/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0988 - mean_absolute_error: 0.1882
# Epoch 51/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0946 - mean_absolute_error: 0.1846
# Epoch 52/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0913 - mean_absolute_error: 0.1853
# Epoch 53/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0883 - mean_absolute_error: 0.1835
# Epoch 54/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0905 - mean_absolute_error: 0.1826
# Epoch 55/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0968 - mean_absolute_error: 0.1878
# Epoch 56/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 0.0862 - mean_absolute_error: 0.1807
# Epoch 57/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0882 - mean_absolute_error: 0.1819
# Epoch 58/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0831 - mean_absolute_error: 0.1779
# Epoch 59/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0919 - mean_absolute_error: 0.1847
# Epoch 60/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0925 - mean_absolute_error: 0.1795
# Epoch 61/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0952 - mean_absolute_error: 0.1790
# Epoch 62/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0924 - mean_absolute_error: 0.1811
# Epoch 63/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0880 - mean_absolute_error: 0.1810
# Epoch 64/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0865 - mean_absolute_error: 0.1782
# Epoch 65/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0908 - mean_absolute_error: 0.1804
# Epoch 66/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0792 - mean_absolute_error: 0.1727
# Epoch 67/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0884 - mean_absolute_error: 0.1784
# Epoch 68/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0834 - mean_absolute_error: 0.1753
# Epoch 69/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0866 - mean_absolute_error: 0.1751
# Epoch 70/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0805 - mean_absolute_error: 0.1755
# Epoch 71/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0914 - mean_absolute_error: 0.1770
# Epoch 72/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0832 - mean_absolute_error: 0.1745
# Epoch 73/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0818 - mean_absolute_error: 0.1718
# Epoch 74/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0802 - mean_absolute_error: 0.1703
# Epoch 75/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0822 - mean_absolute_error: 0.1733
# Epoch 76/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0790 - mean_absolute_error: 0.1723
# Epoch 77/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0804 - mean_absolute_error: 0.1726
# Epoch 78/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0825 - mean_absolute_error: 0.1698
# Epoch 79/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0789 - mean_absolute_error: 0.1701
# Epoch 80/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0803 - mean_absolute_error: 0.1718
# Epoch 81/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 0.0814 - mean_absolute_error: 0.1720
# Epoch 82/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.0825 - mean_absolute_error: 0.1711
# Epoch 83/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0812 - mean_absolute_error: 0.1691
# Epoch 84/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0814 - mean_absolute_error: 0.1688
# Epoch 85/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0840 - mean_absolute_error: 0.1689
# Epoch 86/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0800 - mean_absolute_error: 0.1668
# Epoch 87/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0770 - mean_absolute_error: 0.1678
# Epoch 88/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0780 - mean_absolute_error: 0.1701
# Epoch 89/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0789 - mean_absolute_error: 0.1666
# Epoch 90/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0770 - mean_absolute_error: 0.1667
# Epoch 91/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 0.0778 - mean_absolute_error: 0.1653
# Epoch 92/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.0752 - mean_absolute_error: 0.1642
# Epoch 93/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.0871 - mean_absolute_error: 0.1644
# Epoch 94/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0775 - mean_absolute_error: 0.1656
# Epoch 95/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.0819 - mean_absolute_error: 0.1655
# Epoch 96/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0753 - mean_absolute_error: 0.1642
# Epoch 97/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0751 - mean_absolute_error: 0.1620
# Epoch 98/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0774 - mean_absolute_error: 0.1656
# Epoch 99/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 0.0800 - mean_absolute_error: 0.1667
# Epoch 100/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 0.0813 - mean_absolute_error: 0.1628
# Epoch 101/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.0776 - mean_absolute_error: 0.1622
# Epoch 102/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0760 - mean_absolute_error: 0.1636
# Epoch 103/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0727 - mean_absolute_error: 0.1612
# Epoch 104/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0747 - mean_absolute_error: 0.1600
# Epoch 105/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0795 - mean_absolute_error: 0.1637
# Epoch 106/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0765 - mean_absolute_error: 0.1615
# Epoch 107/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 0.0792 - mean_absolute_error: 0.1622
# Epoch 108/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 0.0753 - mean_absolute_error: 0.1610
# Epoch 109/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.0754 - mean_absolute_error: 0.1622
# Epoch 110/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0836 - mean_absolute_error: 0.1616
# Epoch 111/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0767 - mean_absolute_error: 0.1625
# Epoch 112/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0739 - mean_absolute_error: 0.1603
# Epoch 113/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.0754 - mean_absolute_error: 0.1617
# Epoch 114/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 0.0708 - mean_absolute_error: 0.1566
# Epoch 115/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0740 - mean_absolute_error: 0.1589
# Epoch 116/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 0.0757 - mean_absolute_error: 0.1592
# Epoch 117/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 0.0762 - mean_absolute_error: 0.1594
# Epoch 118/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0776 - mean_absolute_error: 0.1606
# Epoch 119/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 0.0763 - mean_absolute_error: 0.1579
# Epoch 120/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 0.0743 - mean_absolute_error: 0.1595
# Epoch 121/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 0.0757 - mean_absolute_error: 0.1591
# Epoch 122/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 0.0678 - mean_absolute_error: 0.1551
# Epoch 123/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 0.0758 - mean_absolute_error: 0.1602
# Epoch 124/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 0.0717 - mean_absolute_error: 0.1583
# Epoch 125/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 0.0747 - mean_absolute_error: 0.1576
# Epoch 126/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 0.0730 - mean_absolute_error: 0.1580
# Epoch 127/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0742 - mean_absolute_error: 0.1573
# Epoch 128/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0704 - mean_absolute_error: 0.1551
# Epoch 129/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.0740 - mean_absolute_error: 0.1593
# Epoch 130/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 0.0711 - mean_absolute_error: 0.1554
# Epoch 131/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 0.0721 - mean_absolute_error: 0.1556
# Epoch 132/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 0.0845 - mean_absolute_error: 0.1594
# Epoch 133/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 0.0740 - mean_absolute_error: 0.1563
# Epoch 134/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 0.0734 - mean_absolute_error: 0.1561
# Epoch 135/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 0.0720 - mean_absolute_error: 0.1552
# Epoch 136/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 0.0756 - mean_absolute_error: 0.1564
# Epoch 137/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0716 - mean_absolute_error: 0.1556
# Epoch 138/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0699 - mean_absolute_error: 0.1543
# Epoch 139/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 0.0679 - mean_absolute_error: 0.1538
# Epoch 140/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0649 - mean_absolute_error: 0.1504
# Epoch 141/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0792 - mean_absolute_error: 0.1579
# Epoch 142/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0695 - mean_absolute_error: 0.1526
# Epoch 143/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 0.0695 - mean_absolute_error: 0.1544
# Epoch 144/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 0.0725 - mean_absolute_error: 0.1561
# Epoch 145/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 0.0694 - mean_absolute_error: 0.1538
# Epoch 146/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0734 - mean_absolute_error: 0.1545
# Epoch 147/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 0.0687 - mean_absolute_error: 0.1536
# Epoch 148/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - loss: 0.0678 - mean_absolute_error: 0.1525
# Epoch 149/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0724 - mean_absolute_error: 0.1533
# Epoch 150/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0767 - mean_absolute_error: 0.1547
# Epoch 151/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - loss: 0.0650 - mean_absolute_error: 0.1514
# Epoch 152/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 0.0743 - mean_absolute_error: 0.1549
# Epoch 153/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0725 - mean_absolute_error: 0.1524
# Epoch 154/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 0.0700 - mean_absolute_error: 0.1527
# Epoch 155/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0707 - mean_absolute_error: 0.1520
# Epoch 156/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0730 - mean_absolute_error: 0.1525
# Epoch 157/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 0.0670 - mean_absolute_error: 0.1500
# Epoch 158/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0728 - mean_absolute_error: 0.1513
# Epoch 159/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - loss: 0.0723 - mean_absolute_error: 0.1521
# Epoch 160/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 0.0704 - mean_absolute_error: 0.1524
# Epoch 161/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0682 - mean_absolute_error: 0.1515
# Epoch 162/500
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: 0.0688 - mean_absolute_error: 0.1521
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 698ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step

# %%
# Plot the loss function against epochs
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import mean_absolute_error  # Import mean_absolute_error
# Assuming `predicted_df` is a DataFrame with 'Predicted_Open' column
predicted_open_values = predicted_df['Predicted_Open'].values
actual_open=data['Open'][-30:].values
# Ensure both arrays have the same number of elements
print(len(actual_open), len(predicted_open_values))

# Check the first few elements to see where the discrepancy might be
print('Actual Open:', actual_open)
print('Predicted Open:', predicted_open_values)

# Calculate MAE
mae_open = mean_absolute_error(actual_open, predicted_open_values)
print('Mean Absolute Error for Open Prices:', mae_open)
# Out:
# 30 30
# Actual Open: [1011.       1037.       1005.        965.099976  970.950012  953.200012
#   944.        954.        952.        950.        962.5       964.900024
#   959.        946.950012  943.5       931.650024  963.        948.
#   924.950012  940.        940.        977.        973.799988  994.5
#  1002.        990.       1000.        990.        980.        979.      ]
# Predicted Open: [986.8183  988.2804  988.9387  990.5092  991.03796 989.9008  984.4851
#  978.2872  973.12054 973.6685  974.9953  975.55707 975.806   975.87854
#  975.78375 975.56055 975.0056  974.47174 974.08777 973.7103  973.1138
#  972.3547  971.46185 970.4758  969.47925 968.5326  967.68677 966.9634
#  966.3502  965.8281 ]
# Mean Absolute Error for Open Prices: 24.913653612760413

# %%
# Extract the actual last 30 days data
actual_last_30_days = data[-30:]

# Create a DataFrame for the predicted data
predicted_dates = actual_last_30_days.index  # Use the same dates as the actual data
predicted_df = pd.DataFrame(predictions_inverse, index=predicted_dates, columns=['Predicted_Open', 'Predicted_Close', 'Predicted_%_Momentum', 'Predicted_Volatility'])

last_30_open = data['Open'][-30:]
last_30_close = data['Close'][-30:]
last_30_momentum = data['% Momentum'][-30:]
last_30_volatility = data['Volatility'][-30:]

# Step 2: Ensure predicted_df['Predicted_Open'] is also a Series with the same index
predicted_open = predicted_df['Predicted_Open']
predicted_close = predicted_df['Predicted_Close']
predicted_momentum = predicted_df['Predicted_%_Momentum']
predicted_volatility = predicted_df['Predicted_Volatility']
# Step 3: Combine these into a single DataFrame
combined_df_open = pd.DataFrame({
    'Open': last_30_open,
    'Predicted_Open': predicted_open
})
combined_df_close = pd.DataFrame({
    'Open': last_30_close,
    'Predicted_Open': predicted_close
})
combined_df_momentum = pd.DataFrame({
    'Open': last_30_momentum,
    'Predicted_Open': predicted_momentum
})
combined_df_volatility = pd.DataFrame({
    'Open': last_30_volatility,
    'Predicted_Open': predicted_volatility
})
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have already created the combined DataFrames as per your previous code

# Plotting the data
plt.figure(figsize=(18, 12))  # Adjust figure size as needed

# Plot for Open prices
plt.subplot(3, 2, 1)
plt.plot(combined_df_open.index[:7], combined_df_open['Open'][:7], marker='o', linestyle='-', color='b', label='Actual Open')
plt.plot(combined_df_open.index[:7], combined_df_open['Predicted_Open'][:7], marker='o', linestyle='--', color='r', label='Predicted Open')
plt.title('First Week - Open Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

plt.subplot(3, 2, 2)
plt.plot(combined_df_open.index[:14], combined_df_open['Open'][:14], marker='o', linestyle='-', color='b', label='Actual Open')
plt.plot(combined_df_open.index[:14], combined_df_open['Predicted_Open'][:14], marker='o', linestyle='--', color='r', label='Predicted Open')
plt.title('First Fortnight - Open Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

plt.subplot(3, 2, 3)
plt.plot(combined_df_open.index, combined_df_open['Open'], marker='o', linestyle='-', color='b', label='Actual Open')
plt.plot(combined_df_open.index, combined_df_open['Predicted_Open'], marker='o', linestyle='--', color='r', label='Predicted Open')
plt.title('Entire Dataset (30 Readings) - Open Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

# Plot for Close prices
plt.subplot(3, 2, 4)
plt.plot(combined_df_close.index[:7], combined_df_close['Open'][:7], marker='o', linestyle='-', color='b', label='Actual Close')
plt.plot(combined_df_close.index[:7], combined_df_close['Predicted_Open'][:7], marker='o', linestyle='--', color='r', label='Predicted Close')
plt.title('First Week - Close Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

plt.subplot(3, 2, 5)
plt.plot(combined_df_close.index[:14], combined_df_close['Open'][:14], marker='o', linestyle='-', color='b', label='Actual Close')
plt.plot(combined_df_close.index[:14], combined_df_close['Predicted_Open'][:14], marker='o', linestyle='--', color='r', label='Predicted Close')
plt.title('First Fortnight - Close Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

plt.subplot(3, 2, 6)
plt.plot(combined_df_close.index, combined_df_close['Open'], marker='o', linestyle='-', color='b', label='Actual Close')
plt.plot(combined_df_close.index, combined_df_close['Predicted_Open'], marker='o', linestyle='--', color='r', label='Predicted Close')
plt.title('Entire Dataset (30 Readings) - Close Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

# Adjust layout
plt.tight_layout()

# Display the plot
plt.show()
